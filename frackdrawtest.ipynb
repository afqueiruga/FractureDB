# %% [markdown]
# ### testing

# %%
import draw_fracture
from IPython.core import display
import numpy as np
# %matplotlib inline
from matplotlib import pylab as plt
from matplotlib.pyplot import imshow

# %%
im = draw_fracture.draw_fracture(-0.25,0.25,0.25,-0.5,size=(28,28))

# %%
imshow(np.array(im,dtype=np.float32))

# %%
for tip_x in np.linspace(-0.8,0.9,5):
    for tip_y in np.linspace(-0.8,0.8,5):
        for crook_x in np.linspace(-0.8, tip_x-0.1, 5):
            for crook_y in np.linspace( -0.8,0.8, 3):
                print tip_x, tip_y
                im = draw_fracture.draw_fracture( crook_x,crook_y, tip_x, tip_y, size=(28,28))
                imshow(im)
#                 plt.show()
# Out:
# -0.8 -0.8
# -0.8 -0.8
# -0.8 -0.8
# -0.8 -0.8
# -0.8 -0.8
# -0.8 -0.8
# -0.8 -0.8
# -0.8 -0.8
# -0.8 -0.8
# -0.8 -0.8
# -0.8 -0.8
# -0.8 -0.8
# -0.8 -0.8
# -0.8 -0.8
# -0.8 -0.8
# -0.8 -0.4
# -0.8 -0.4
# -0.8 -0.4
# -0.8 -0.4
# -0.8 -0.4
# -0.8 -0.4
# -0.8 -0.4
# -0.8 -0.4
# -0.8 -0.4
# -0.8 -0.4
# -0.8 -0.4
# -0.8 -0.4
# -0.8 -0.4
# -0.8 -0.4
# -0.8 -0.4
# -0.8 0.0
# -0.8 0.0
# -0.8 0.0
# -0.8 0.0
# -0.8 0.0
# -0.8 0.0
# -0.8 0.0
# -0.8 0.0
# -0.8 0.0
# -0.8 0.0
# -0.8 0.0
# -0.8 0.0
# -0.8 0.0
# -0.8 0.0
# -0.8 0.0
# -0.8 0.40000000000000013
# -0.8 0.40000000000000013
# -0.8 0.40000000000000013
# -0.8 0.40000000000000013
# -0.8 0.40000000000000013
# -0.8 0.40000000000000013
# -0.8 0.40000000000000013
# -0.8 0.40000000000000013
# -0.8 0.40000000000000013
# -0.8 0.40000000000000013
# -0.8 0.40000000000000013
# -0.8 0.40000000000000013
# -0.8 0.40000000000000013
# -0.8 0.40000000000000013
# -0.8 0.40000000000000013
# -0.8 0.8
# -0.8 0.8
# -0.8 0.8
# -0.8 0.8
# -0.8 0.8
# -0.8 0.8
# ...

# %%
im
# Out:
# <PIL.Image.Image image mode=1 size=28x28 at 0x11936D250>

# %%
im[0,0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-cb226c7cda2c> in <module>()
# ----> 1 im[0,0]
#
# TypeError: 'Image' object has no attribute '__getitem__'

# %%
im.getpixel(0,0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-e0ed9152c8c7> in <module>()
# ----> 1 im.getpixel(0,0)
#
# TypeError: getpixel() takes exactly 2 arguments (3 given)
