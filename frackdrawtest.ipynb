# %% [markdown]
# ### testing

# %%
import draw_fracture
from IPython.core import display
import numpy as np
# %matplotlib inline
from matplotlib import pylab as plt
from matplotlib.pyplot import imshow

# %%
im = draw_fracture.draw_fracture(-0.25,0.25,0.25,-0.5,size=(28,28))

# %%
imshow(np.array(im,dtype=np.float32))

# %%
for tip_x in np.linspace(-0.3,0.4,5):
    for tip_y in np.linspace(-0.5,0.5,5):
        for crook_x in np.linspace(-0.4, tip_x-0.1, 5):
            for crook_y in np.linspace( -0.3,0.3, 3):
                print tip_x, tip_y
                im = draw_fracture.draw_fracture( crook_x,crook_y, tip_x, tip_y, size=(28,28))
                imshow(im)
                plt.show()
# Out:
# -0.3 -0.5
# -0.3 -0.5
# -0.3 -0.5
# -0.3 -0.5
# -0.3 -0.5
# -0.3 -0.5
# -0.3 -0.5
# -0.3 -0.5
# -0.3 -0.5
# -0.3 -0.5
# -0.3 -0.5
# -0.3 -0.5
# -0.3 -0.5
# -0.3 -0.5
# -0.3 -0.5
# -0.3 -0.25
# -0.3 -0.25
# -0.3 -0.25
# -0.3 -0.25
# -0.3 -0.25
# -0.3 -0.25
# -0.3 -0.25
# -0.3 -0.25
# -0.3 -0.25
# -0.3 -0.25
# -0.3 -0.25
# -0.3 -0.25
# -0.3 -0.25
# -0.3 -0.25
# -0.3 -0.25
# -0.3 0.0
# -0.3 0.0
# -0.3 0.0
# -0.3 0.0
# -0.3 0.0
# -0.3 0.0
# -0.3 0.0
# -0.3 0.0
# -0.3 0.0
# -0.3 0.0
# -0.3 0.0
# -0.3 0.0
# -0.3 0.0
# -0.3 0.0
# -0.3 0.0
# -0.3 0.25
# -0.3 0.25
# -0.3 0.25
# -0.3 0.25
# -0.3 0.25
# -0.3 0.25
# -0.3 0.25
# -0.3 0.25
# -0.3 0.25
# -0.3 0.25
# -0.3 0.25
# -0.3 0.25
# -0.3 0.25
# -0.3 0.25
# -0.3 0.25
# -0.3 0.5
# -0.3 0.5
# -0.3 0.5
# -0.3 0.5
# -0.3 0.5
# -0.3 0.5
# -0.3 0.5
# -0.3 0.5
# -0.3 0.5
# -0.3 0.5
# -0.3 0.5
# -0.3 0.5
# -0.3 0.5
# -0.3 0.5
# -0.3 0.5
# -0.125 -0.5
# -0.125 -0.5
# -0.125 -0.5
# -0.125 -0.5
# -0.125 -0.5
# -0.125 -0.5
# -0.125 -0.5
# -0.125 -0.5
# ...
